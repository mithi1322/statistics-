# %% [markdown]
# Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5 using Python. Interpret the results.

# %%
from scipy import stats
import numpy as np

# sample data
sample_mean = 50
sample_std = 5
n = 100

# calculate standard error
se = sample_std / np.sqrt(n)

# calculate the confidence interval
ci = stats.norm.interval(0.95, loc=sample_mean, scale=se)

# print the results
print("The 95% confidence interval is:", ci)
# Out:
# The 95% confidence interval is: (49.02001800772997, 50.97998199227003)

# %% [markdown]
# Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
# matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
# brown. Use Python to perform the test with a significance level of 0.05.

# %%
from scipy.stats import chisquare

observed = [42, 38, 35, 20, 22, 43]
expected = [40, 40, 40, 20, 20, 40]

test_statistic, p_value = chisquare(observed, f_exp=expected)

print("Test statistic:", test_statistic)
print("p-value:", p_value)
# Out:
# Test statistic: 1.25
# p-value: 0.9399915602888446

# %% [markdown]
# Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following
# data:
#             Group A          Group B
# Outcome 1    20                15
# Outcome 2    10                25
# Outcome 3    15                20
#
# Interpret the results of the test.

# %%
import numpy as np
from scipy.stats import chi2_contingency

observed = np.array([[20, 15], [10, 25], [15, 20]])
chi2, p, dof, expected = chi2_contingency(observed)

print("Chi-square statistic:", chi2)
print("P-value:", p)
# Out:
# Chi-square statistic: 5.833333333333334
# P-value: 0.05411376622282158

# %% [markdown]
# Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals
# smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the
# population who smoke.

# %%
import statsmodels.stats.proportion as smp

n = 500
smokers = 60
alpha = 0.05

conf_int = smp.proportion_confint(smokers, n, alpha=alpha, method='normal')
print(conf_int)
# Out:
# (0.09151638887130706, 0.14848361112869293)

# %% [markdown]
# Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.

# %%
import scipy.stats as stats

sample_mean = 75
sample_std = 12
n = 50
confidence_level = 0.90

# Calculate the standard error
std_error = sample_std / (n ** 0.5)

# Calculate the margin of error
margin_error = stats.t.ppf((1 + confidence_level) / 2, n - 1) * std_error

# Calculate the confidence interval
lower_bound = sample_mean - margin_error
upper_bound = sample_mean + margin_error

print(f"The resulting confidence interval is :{lower_bound,upper_bound}")
# Out:
# The resulting confidence interval is :(72.15479878877537, 77.84520121122463)

# %% [markdown]
# Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
# area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

df = 10  # degrees of freedom
x = np.linspace(0, 25, 500)  # range of chi-square values to plot
plt.plot(x, chi2.pdf(x, df), 'b-', lw=2)  # plot chi-square pdf
plt.fill_between(x[x >= 15], chi2.pdf(x[x >= 15], df), 0, color='gray', alpha=0.5)  # shade area
plt.axvline(x=15, color='r', linestyle='--', lw=2)  # vertical line at chi-square=15
plt.xlabel('Chi-Square Value')
plt.ylabel('Probability Density')
plt.title('Chi-Square Distribution with 10 Degrees of Freedom')
plt.show()

# %% [markdown]
# Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
# preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
# prefer Coke.

# %%
# Answer:
'''
To calculate the confidence interval, we can use the formula:

CI = p ± z * sqrt((p * (1 - p)) / n)

where:

p is the sample proportion
z is the z-score corresponding to the desired confidence level (99% in this case)
n is the sample size
First, we calculate the sample proportion:
p = 520 / 1000 = 0.52

Next, we find the z-score:
z = 2.576 (from a standard normal distribution table)

Finally, we plug in the values and calculate the confidence interval:
CI = 0.52 ± 2.576 * sqrt((0.52 * 0.48) / 1000)
= (0.485, 0.555)

Therefore, we can say with 99% confidence that the true proportion of people in the population who prefer Coke is between 0.485 and 0.555.
'''
# Out:
# '\nTo calculate the confidence interval, we can use the formula:\n\nCI = p ± z * sqrt((p * (1 - p)) / n)\n\nwhere:\n\np is the sample proportion\nz is the z-score corresponding to the desired confidence level (99% in this case)\nn is the sample size\nFirst, we calculate the sample proportion:\np = 520 / 1000 = 0.52\n\nNext, we find the z-score:\nz = 2.576 (from a standard normal distribution table)\n\nFinally, we plug in the values and calculate the confidence interval:\nCI = 0.52 ± 2.576 * sqrt((0.52 * 0.48) / 1000)\n= (0.485, 0.555)\n\nTherefore, we can say with 99% confidence that the true proportion of people in the population who prefer Coke is between 0.485 and 0.555.\n'

# %% [markdown]
# Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
# 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
# expected frequencies of a fair coin. Use a significance level of 0.05.

# %%
from scipy.stats import chisquare

observed = [55, 45]
expected = [50, 50]

statistic, p_value = chisquare(observed, expected)

print("Chi-square statistic:", statistic)
print("P-value:", p_value)
# Out:
# Chi-square statistic: 1.0
# P-value: 0.31731050786291115

# %% [markdown]
# Q9. A study was conducted to determine if there is an association between smoking status (smoker or
# non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
# Conduct a chi-square test for independence to determine if there is a significant association between
# smoking status and lung cancer diagnosis.
#
#                         Lung Cancer: Yes              Lung Cancer: No
#
# Smoker                      60                           140
# Non-smoker                  30                           170
#
# Use a significance level of 0.05.

# %%
from scipy.stats import chi2_contingency

observed = [[60, 140], [30, 170]]
chi2, p, dof, expected = chi2_contingency(observed)

print("Chi-square statistic:", chi2)
print("p-value:", p)
# Out:
# Chi-square statistic: 12.057347670250895
# p-value: 0.0005158863863703744

# %% [markdown]
# Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark
# chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from
# the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the
# contingency table below. Conduct a chi-square test for independence to determine if there is a significant
# association between chocolate preference and country of origin.
#
#                     Milk Chocolate     Dark Chocolate     White Chocolate
#
# U.S. (n=500)           200                 150               150
# U.K. (n=500)           225                 175               100
#
# Use a significance level of 0.01.

# %%
from scipy.stats import chi2_contingency

# Create the contingency table
obs = [[200, 150, 150], [225, 175, 100]]

# Perform the chi-square test for independence
chi2, p, dof, expected = chi2_contingency(obs)

# Output the results
print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-square statistic: 13.393665158371041
# P-value: 0.0012348168997745918

# %% [markdown]
# Q11. A random sample of 30 people was selected from a population with an unknown mean and standard
# deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10.
# Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a
# significance level of 0.05.

# %%
# We can calculate the t-value and p-value using Python:
import numpy as np
from scipy.stats import t

sample_mean = 72
sample_std = 10
n = 30
pop_mean = 70

# Calculate the t-value
t_value = (sample_mean - pop_mean) / (sample_std / np.sqrt(n))

# Find the p-value
p_value = 2 * (1 - t.cdf(abs(t_value), n - 1))

print("t-value: ", t_value)
print("p-value: ", p_value)

# The t-value is 1.2 and the p-value is 0.239. Since the p-value is greater than 0.05, we fail to reject the null hypothesis. 
# Therefore, we do not have enough evidence to suggest that the population mean is significantly different from 70.
# Out:
# t-value:  1.0954451150103321
# p-value:  0.2823362372860698
